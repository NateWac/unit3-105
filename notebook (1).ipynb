# %% [markdown]
# # Overview of Basic Data
# Generally, this data shows the county health data and what it shows inside. On the inside it shows the differnt sets of data and how they interact with each other and relate between in each other. With the data set, the chosen 3 are Adult Smoking, Adult Obesity and Food environment index.
#
# ## What will happen with the data?
#
# You will be able to play with the data and understand how it works, generally finding out how to code it within and using the code to see how it can interact with each other.
#
# ### Steps one will do:
#
# 1. Download it as a .csv file
# 2. See the columns and size of it
# 3. Use the data to your liking

# %% [markdown]
# # Step 1
# For the first one, you would generally find a csv file, combine it to the folder of this related file so it shos in the left side where the pythons are.
#
# 1. Make a folder with all the needed documents
#     2. Name it **Unit Data**
# 3. Find the .csv file CountyHealthData_2014-2015.csv
# 4. Download it and put the file in the **Unit Data** folder
# 5. Open Anaconda and open **Unit Data** folder
# 6. The .csv file should be there

# %% [markdown]
# ## Step 2
# When done with that, one should generally have .csv file and the option to use it. Next, is python. Follow the steps in **order**
#
# Begin by importing the pandas package using the following command:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# This allows us to call functions from pandas with pd.<function> instead of pandas.<function> for convenience. as pd is not necessary to load the package.
#
# Note, we also imported the **numpy** package, which is going to help pandas do some of its math.

# %% [markdown]
# ## Step 3
#
# With this information, one is now able to download the file and use it according to how one can use it normally.
#
# For the next Step:
#
# `pd.read_csv` reads the tabular data from a Comma Separated Values (csv) file into a dataframe object that we'll define as `df`.
# One will be using that function to be able to read the file in the Anaconda python.

# %%
df=pd.read_csv("CountyHealthData_2014-2015.csv")

# %% [markdown]
# ## Step 4
#
# Determining the shape and columns are not needed due to the fact that one is going to cut out a certain point of data and use it for their liking
#
# Type this:

# %%
df [0:9]
# Out:
#   State Region Division                        County  FIPS  GEOID  \
# 0    AK   West  Pacific    Aleutians West Census Area  2016   2016
# 1    AK   West  Pacific    Aleutians West Census Area  2016   2016
# 2    AK   West  Pacific             Anchorage Borough  2020   2020
# 3    AK   West  Pacific             Anchorage Borough  2020   2020
# 4    AK   West  Pacific            Bethel Census Area  2050   2050
# 5    AK   West  Pacific            Bethel Census Area  2050   2050
# 6    AK   West  Pacific        Dillingham Census Area  2070   2070
# 7    AK   West  Pacific        Dillingham Census Area  2070   2070
# 8    AK   West  Pacific  Fairbanks North Star Borough  2090   2090
#
#     SMS Region      Year  Premature death  Poor or fair health  ...  \
# 0  Insuff Data  1/1/2014              NaN                0.122  ...
# 1  Insuff Data  1/1/2015              NaN                0.122  ...
# 2    Region 22  1/1/2014           6827.0                0.125  ...
# ...

# %% [markdown]
# This is the rows and columns you will be using specifically in, **Adult Smoking, Adult Obesity and Food environment index.**

# %% [markdown]
# ## Step 5
#
# When finishing typing that, you will type:
#
# df[["State", "Year", "County", "Adult smoking"]][0:9]
#
# This shows the State, the Year, the County and the data set we will be taking from 0-9

# %%
df[["State", "Year", "County", "Adult smoking"]][0:9]

# %% [markdown]
# When finishing typing that as well, type:
#
# df[["State", "Year", "County", "Adult obesity"]][0:9]
#
# This shows the State, the Year, the County and the data set we will be taking from 0-9

# %%
df[["State", "Year", "County", "Adult obesity"]][0:9]

# %% [markdown]
# When finishing typing that as well, type:
#
# df[["State", "Year", "County", "Food environment index"]][0:9]
#
# This shows the State, the Year, the County and the data set we will be taking from 0-9

# %%
df[["State", "Year", "County", "Food environment index"]][0:9]
# Out:
#   State      Year                        County  Food environment index
# 0    AK  1/1/2014    Aleutians West Census Area                   7.002
# 1    AK  1/1/2015    Aleutians West Census Area                   6.600
# 2    AK  1/1/2014             Anchorage Borough                   8.185
# 3    AK  1/1/2015             Anchorage Borough                   8.000
# 4    AK  1/1/2014            Bethel Census Area                   3.210
# 5    AK  1/1/2015            Bethel Census Area                   2.800
# 6    AK  1/1/2014        Dillingham Census Area                   5.892
# 7    AK  1/1/2015        Dillingham Census Area                   5.800
# 8    AK  1/1/2014  Fairbanks North Star Borough                   7.526

# %% [markdown]
# ![](english105data.jp
# <img src="english105data.jpg" style="width:200px;height:400px"/>
